# %% [markdown]
# # Model Performance

# %% [markdown]
# ## Here are the results of the first run
#
# ###Epoch 1/10
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###9s 49ms/step - accuracy: 0.5879 - loss: 11.9083 - val_accuracy: 0.8375 - val_loss: 0.3811
# ###Epoch 2/10
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 13ms/step - accuracy: 0.8779 - loss: 0.2941 - val_accuracy: 0.8537 - val_loss: 0.3606
# ###Epoch 3/10
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 13ms/step - accuracy: 0.9371 - loss: 0.1764 - val_accuracy: 0.8925 - val_loss: 0.3040
# ###Epoch 4/10
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 13ms/step - accuracy: 0.9739 - loss: 0.0969 - val_accuracy: 0.8637 - val_loss: 0.3547
# ###Epoch 5/10
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 14ms/step - accuracy: 0.9802 - loss: 0.0656 - val_accuracy: 0.8975 - val_loss: 0.3382
# ###Epoch 6/10
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 13ms/step - accuracy: 0.9991 - loss: 0.0159 - val_accuracy: 0.8963 - val_loss: 0.3496
# ###Epoch 7/10
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 14ms/step - accuracy: 0.9999 - loss: 0.0074 - val_accuracy: 0.8875 - val_loss: 0.3584
# ###Epoch 8/10
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 14ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8900 - val_loss: 0.3852
# ###Epoch 9/10
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 13ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8875 - val_loss: 0.3959
# ###Epoch 10/10
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 13ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8888 - val_loss: 0.4150
#
# This shows overfitting by the accuracy becoming 1 at epoch 8.  The loss rate is heading done which is good.  The val_accuracy increases which is good, but then flucuates.  Finally the val_loss does decrease which is good, but then increases which is a sign of overfitting.  I will decrease the number of epoch to prevent overfitting.

# %% [markdown]
# ## Results for second run
#
# ###Epoch 1/7
# ###100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.6284 - loss: 8.9138 - val_accuracy: 0.8438 - val_loss: 0.3961
# ###Epoch 2/7
# ###100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9304 - loss: 0.1963 - val_accuracy: 0.8500 - val_loss: 0.3682
# ###Epoch 3/7
# ###100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9789 - loss: 0.0702 - val_accuracy: 0.8750 - val_loss: 0.3349
# ###Epoch 4/7
# ###100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9986 - loss: 0.0168 - val_accuracy: 0.8700 - val_loss: 0.3794
# ###Epoch 5/7
# ###100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9992 - loss: 0.0059 - val_accuracy: 0.8800 - val_loss: 0.4324
# ###Epoch 6/7
# ###100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8788 - val_loss: 0.4360
# ###Epoch 7/7
# ###100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8788 - val_loss: 0.4622
#
# Again, we have overfitting.  Going to reduce the epochs even more.

# %% [markdown]
# ## Results of third run
#
# ###Epoch 1/5
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###8s 49ms/step - accuracy: 0.6368 - loss: 6.4286 - val_accuracy: 0.8487 - val_loss: 0.3607
# ###Epoch 2/5
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 14ms/step - accuracy: 0.9284 - loss: 0.2027 - val_accuracy: 0.8850 - val_loss: 0.3040
# ###Epoch 3/5
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 13ms/step - accuracy: 0.9879 - loss: 0.0646 - val_accuracy: 0.8712 - val_loss: 0.3316
# ###Epoch 4/5
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 14ms/step - accuracy: 0.9982 - loss: 0.0224 - val_accuracy: 0.8750 - val_loss: 0.3659
# ###Epoch 5/5
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 13ms/step - accuracy: 0.9996 - loss: 0.0090 - val_accuracy: 0.8813 - val_loss: 0.3781
#
# Here almost everything fits.  Accuracy is just under 100. Loss keeps decreasing. Val_accuracy only goes up, but val_loss goes down and then increases.  I will further reduce epochs.

# %% [markdown]
# ## Results of fourth run
#
# ###Epoch 1/3
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###8s 51ms/step - accuracy: 0.6743 - loss: 6.0488 - val_accuracy: 0.8788 - val_loss: 0.2935
# ###Epoch 2/3
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 13ms/step - accuracy: 0.9415 - loss: 0.1700 - val_accuracy: 0.8725 - val_loss: 0.3414
# ###Epoch 3/3
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 14ms/step - accuracy: 0.9773 - loss: 0.0732 - val_accuracy: 0.8900 - val_loss: 0.2951
#
# Now these results are strange.  Accuracy goes up.  Loss goes down.  Val_accuracy flucuates, and Val_loss flucuates as well. I'll try 4 epochs now.

# %% [markdown]
# ## Results of fourth run
#
# ##Epoch 1/4
# ##100/100 ━━━━━━━━━━━━━━━━━━━━
# ###8s 49ms/step - accuracy: 0.5931 - loss: 3.7509 - val_accuracy: 0.8388 - val_loss: 0.4178
# ###Epoch 2/4
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 13ms/step - accuracy: 0.8915 - loss: 0.2834 - val_accuracy: 0.8750 - val_loss: 0.3063
# ###Epoch 3/4
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 13ms/step - accuracy: 0.9731 - loss: 0.1116 - val_accuracy: 0.8838 - val_loss: 0.3089
# ###Epoch 4/4
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 14ms/step - accuracy: 0.9944 - loss: 0.0431 - val_accuracy: 0.8825 - val_loss: 0.3540
#
# Now this looks about the same as 3.  Accuracy increases, Loss decreases, Val_accuracy goes up and at the end goes down, and Val_loss goes down and then flucuates.

# %% [markdown]
# ## Final Run
#
# ###Epoch 1/2
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###8s 51ms/step - accuracy: 0.5934 - loss: 7.3303 - val_accuracy: 0.8500 - val_loss: 0.3615
# ###Epoch 2/2
# ###100/100 ━━━━━━━━━━━━━━━━━━━━
# ###1s 14ms/step - accuracy: 0.9215 - loss: 0.2078 - val_accuracy: 0.8800 - val_loss: 0.3150
#
# This one looks the best.  Accuracy goes up to 92%, Loss drop by a lot, VaL_accuracy only goes up and reaches 88%, and Val_loss drops.

# %% [markdown]
# ## Conclusion, this model works best with two iterations.
